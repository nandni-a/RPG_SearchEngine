# %%
import google.generativeai as genai

# Replace with your actual Gemini API key
API_KEY = "AIzaSyDlVCKsmkbHbQHl49zHkzbBbQ7iTRmdBSM"

# Configure the API
genai.configure(api_key=API_KEY)

# Initialize the Gemini model (Gemini 1.5 Pro is recommended)
model = genai.GenerativeModel(model_name="gemini-2.0-flash")

# Example prompt
prompt = "Explain the theory of relativity in simple terms."

# Generate a response
response = model.generate_content(prompt)

# Print the result
print("Gemini response:")
print(response.text)
# Out:
# Gemini response:
# Okay, let's break down the theory of relativity in simple terms. It's actually TWO theories, and both were developed by Albert Einstein.
#
# **1. Special Relativity (1905): Deals with objects moving at constant speeds.**
#
# Imagine you're on a train moving smoothly at a constant speed, and you're tossing a ball straight up in the air.  To you, the ball goes straight up and straight down.
#
# Now, imagine someone is standing on the ground watching the train go by.  To them, the ball is going up and down *and* moving forward with the train. So, the ball is tracing a diagonal path.
#
# Special Relativity says:
#
# *   **The laws of physics are the same for everyone moving at a constant speed in a straight line, regardless of their relative speed.** This means whether you're on the train or on the ground, the laws of physics still apply.  You can do the same experiment and get the same results.
#
# *   **The speed of light in a vacuum (represented by the letter 'c') is the same for everyone, no matter how fast they are moving.**  This is the weird one.  Imagine you're chasing a beam of light.  You might think you'd be able to catch up a little bit, so the light seems to be moving slower relative to you. Nope!  The light will *always* appear to be moving at the speed of light, regardless of how fast you're chasing it.
#
# **So what are the consequences of these rules?  Here are the big ones:**
#
# *   **Time Dilation:** Time passes slower for objects that are moving faster relative to an observer. If your friend is on a spaceship zooming by at near the speed of light, time will appear to pass slower for them compared to you.  This isn't an illusion; it's a real physical effect.
#
# *   **Length Contraction:** Objects appear shorter in the direction they are moving if they are moving very fast relative to an observer. That spaceship would look shorter to you.
#
# *   **Mass Increase:** As an object's speed increases, its mass increases.  The faster it goes, the harder it is to accelerate it even more.
#
# *   **E=mc²:** This is the famous equation. It says that energy (E) and mass (m) are equivalent and can be converted into each other. The 'c²' just means that a small amount of mass can be converted into a *huge* amount of energy. This is the basis for nuclear power and nuclear weapons.
#
# **Key takeaway:** Special relativity only applies to constant speeds and straight lines.
#
# **2. General Relativity (1915): Deals with gravity and acceleration.**
#
# General Relativity says that **gravity is not a force, but a curvature of spacetime caused by mass and energy.**
#
# Think of it like this:
#
# *   Imagine a trampoline (that's spacetime).
#
# *   If you put a bowling ball in the center of the trampoline (that's a massive object like the Sun), it will create a dip in the trampoline.
#
# *   If you roll a marble across the trampoline (that's a planet), it will curve around the bowling ball because of the dip in the trampoline.  That curved path is what we perceive as gravity.
#
# **So, what are the consequences of General Relativity?**
#
# *   **Gravity bends light:** Because spacetime is curved, even light bends when it passes near massive objects.
#
# *   **Gravitational Time Dilation:**  Time passes slower in stronger gravitational fields.  Time passes slightly slower at sea level than on top of a mountain, because you're closer to the Earth's mass at sea level.  This is a tiny difference in everyday life, but it's significant for very precise clocks used in things like GPS satellites.
#
# *   **Black Holes:** These are regions of spacetime where gravity is so strong that nothing, not even light, can escape.
#
# *   **Expansion of the Universe:** General Relativity provides the framework for understanding the expansion of the universe.
#
# *   **Gravitational Waves:**  Ripples in spacetime caused by accelerating massive objects.  Think of it like dropping a rock in a pond.  These were predicted by Einstein and were directly detected in 2015, confirming a key prediction of general relativity.
#
# **Key Takeaways:**
#
# *   General relativity explains gravity as a curvature of spacetime.
# *   Mass and energy warp spacetime, affecting how objects move (including light) and how time passes.
#
# **In Summary:**
#
# *   **Special Relativity:** How space and time are related for objects moving at constant speeds. The speed of light is constant for everyone.  Leads to time dilation, length contraction, and E=mc².
# *   **General Relativity:** Gravity is not a force, but the curvature of spacetime caused by mass and energy. Leads to bending of light, gravitational time dilation, black holes, and gravitational waves.
#
# These theories are complex, but hopefully, this explanation gives you a basic understanding of what they are all about. They revolutionized our understanding of the universe.
